# %%
# import statements
# remove unused imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing  import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor

from sklearn.svm import SVR
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/Users/sahithipriya/Downloads/sales-forecasting/train.csv")
df_test = pd.read_csv("/Users/sahithipriya/Downloads/sales-forecasting/test.csv")

# %%
df_test.head()
# Out:
#    ID Company Quarter  QuickRatio  InventoryRatio  RevenueGrowth  \
# 0   7   CMP01      Q8        1.93            2.79          -0.03
# 1   8   CMP01      Q9        1.93            4.77           0.00
# 2  16   CMP02      Q8        1.97            2.34           0.04
# 3  17   CMP02      Q9        1.93            4.14           0.04
# 4  25   CMP03      Q8        0.67             NaN          -0.05
#
#    MarketshareChange Bond rating Stock rating Region           Industry
# 0              -0.01         CCC          Buy  South  Metal Fabrication
# 1               0.00         CCC          Buy  South  Metal Fabrication
# 2              -0.03           A         Sell   West     Infrastructure
# 3               0.01         BBB         Hold   West     Infrastructure
# 4              -0.01          BB          Buy   East     Infrastructure

# %%
df.head()
# df.dropna(inplace=True)
# Out:
#    ID Company Quarter  QuickRatio  InventoryRatio  RevenueGrowth  \
# 0   0   CMP01      Q1        2.02            7.71           0.05
# 1   1   CMP01      Q2        2.01            4.10           0.03
# 2   2   CMP01      Q3        2.02            6.79           0.06
# 3   3   CMP01      Q4        1.98            3.97           0.01
# 4   4   CMP01      Q5        1.96            7.41          -0.07
#
#    MarketshareChange Bond rating Stock rating Region           Industry  \
# 0              -0.04         CCC          Buy  South  Metal Fabrication
# 1               0.00         CCC         Hold  South  Metal Fabrication
# 2              -0.02         CCC          Buy  South  Metal Fabrication
# 3               0.02         CCC          Buy  South  Metal Fabrication
# 4               0.02         CCC          Buy  South  Metal Fabrication
#
#     Sales
# 0  1517.0
# 1  2968.0
# 2  1497.0
# 3  2929.0
# 4  1452.0

# %%
df_test.head()
# Out:
#    ID Company Quarter  QuickRatio  InventoryRatio  RevenueGrowth  \
# 0   7   CMP01      Q8        1.93            2.79          -0.03
# 1   8   CMP01      Q9        1.93            4.77           0.00
# 2  16   CMP02      Q8        1.97            2.34           0.04
# 3  17   CMP02      Q9        1.93            4.14           0.04
# 4  25   CMP03      Q8        0.67             NaN          -0.05
#
#    MarketshareChange Bond rating Stock rating Region           Industry
# 0              -0.01         CCC          Buy  South  Metal Fabrication
# 1               0.00         CCC          Buy  South  Metal Fabrication
# 2              -0.03           A         Sell   West     Infrastructure
# 3               0.01         BBB         Hold   West     Infrastructure
# 4              -0.01          BB          Buy   East     Infrastructure

# %%
df_test.shape
# Out:
# (150, 11)

# %%
# removing colums in df
df = df.drop(["ID","Quarter"], axis=1)
df.dropna(subset=['Sales'], inplace=True)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy="mean"), ["InventoryRatio"]),
        ('BondRating',OneHotEncoder(),['Bond rating']),
        ('StockRating',OneHotEncoder(),['Stock rating']),
        ('Region',OneHotEncoder(),['Region']),
        ('Industry',OneHotEncoder(),['Industry']),
        ('Company',OneHotEncoder(),['Company']),
    ],
    remainder='passthrough'
)

# %%
X = df.drop(columns=["Sales"])
Y = df["Sales"]

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
testing = preprocessor.fit_transform(X_train)
testing
# Out:
# <420x98 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3668 stored elements in Compressed Sparse Row format>

# %%
# model = Pipeline(
#     steps=[
#         ('preprocessor',preprocessor),
#         ('regressor',LinearRegression())
# ])
model = Pipeline(
    steps=[
        ('preprocessor',preprocessor),
        #('regressor',ExtraTreesRegressor(n_estimators=100, random_state=42))
        ('ann', MLPRegressor(hidden_layer_sizes=(150, 100, 50), activation='relu', solver='adam', max_iter=1000))
])

# %%
model.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', SimpleImputer(),
#                                                   ['InventoryRatio']),
#                                                  ('BondRating', OneHotEncoder(),
#                                                   ['Bond rating']),
#                                                  ('StockRating',
#                                                   OneHotEncoder(),
#                                                   ['Stock rating']),
#                                                  ('Region', OneHotEncoder(),
#                                                   ['Region']),
#                                                  ('Industry', OneHotEncoder(),
#                                                   ['Industry']),
#                                                  ('Company', OneHotEncoder(),
#                                                   ['Company'])])),
#                 ('ann',
#                  MLPRegressor(hidden_layer_sizes=(150, 100, 50),
#                               max_iter=1000))])

# %%
train_score = model.score(X_train, Y_train)
test_score = model.score(X_test, Y_test)

print(f"Training R^2 score: {train_score:.2f}")
print(f"Testing R^2 score: {test_score:.2f}")
# Out:
# Training R^2 score: 0.86
# Testing R^2 score: 0.69

# %%
#model.fit(X,Y)

# %%
#train_score = model.score(X,Y)
#print(f"Training R^2 score: {train_score:.2f}")

# %%
idDF_test = df_test["ID"]

# %%
df_test = df_test.drop(["ID","Quarter"], axis=1)
df_test.head()
# Out:
#   Company  QuickRatio  InventoryRatio  RevenueGrowth  MarketshareChange  \
# 0   CMP01        1.93            2.79          -0.03              -0.01
# 1   CMP01        1.93            4.77           0.00               0.00
# 2   CMP02        1.97            2.34           0.04              -0.03
# 3   CMP02        1.93            4.14           0.04               0.01
# 4   CMP03        0.67             NaN          -0.05              -0.01
#
#   Bond rating Stock rating Region           Industry
# 0         CCC          Buy  South  Metal Fabrication
# 1         CCC          Buy  South  Metal Fabrication
# 2           A         Sell   West     Infrastructure
# 3         BBB         Hold   West     Infrastructure
# 4          BB          Buy   East     Infrastructure

# %%
df_test.head(200)
#final = model.predict(df_test)
# Out:
#     Company  QuickRatio  InventoryRatio  RevenueGrowth  MarketshareChange  \
# 0     CMP01        1.93            2.79          -0.03              -0.01
# 1     CMP01        1.93            4.77           0.00               0.00
# 2     CMP02        1.97            2.34           0.04              -0.03
# 3     CMP02        1.93            4.14           0.04               0.01
# 4     CMP03        0.67             NaN          -0.05              -0.01
# ..      ...         ...             ...            ...                ...
# 145   CMP73        0.93             NaN           0.01               0.01
# 146   CMP74        1.30            6.18           0.00              -0.02
# 147   CMP74        1.28            4.96           0.04               0.01
# 148   CMP75        2.21            5.43           0.04               0.01
# 149   CMP75        2.21            2.60          -0.07              -0.02
#
#     Bond rating Stock rating Region           Industry
# 0           CCC          Buy  South  Metal Fabrication
# 1           CCC          Buy  South  Metal Fabrication
# 2             A         Sell   West     Infrastructure
# 3           BBB         Hold   West     Infrastructure
# 4            BB          Buy   East     Infrastructure
# ..          ...          ...    ...                ...
# 145         BBB          Buy   West         Automobile
# 146          AA          Buy  South  Metal Fabrication
# 147          AA          Buy  South  Metal Fabrication
# 148         BBB         Hold   West         Automobile
# 149          BB         Sell   West         Automobile
#
# [150 rows x 9 columns]

# %%
final = model.predict(df_test)

# %%
print(type(final))
# Out:
# <class 'numpy.ndarray'>

# %%
predictions = pd.DataFrame(final,columns=["Sales"])

# %%
#result = pd.concat([idDF_test,predictions],axis=1)
#result.to_csv("projsub2.csv",index=False)
